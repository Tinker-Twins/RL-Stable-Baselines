# %% [markdown]
# # Stable Baselines - Hindsight Experience Replay on Highway Env
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
# Highway env: [https://github.com/eleurent/highway-env](https://github.com/eleurent/highway-env)
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a training framework for Reinforcement Learning (RL), using Stable Baselines3.
#
# It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# for autoformatting
# %load_ext jupyter_black

# %%
# Install stable-baselines latest version
# !pip install "stable-baselines3[extra]>=2.0.0a4"

# %%
# Install highway-env
# !pip install highway-env

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
import gymnasium as gym
import highway_env
import numpy as np

from stable_baselines3 import HerReplayBuffer, SAC, DDPG
from stable_baselines3.common.noise import NormalActionNoise

import imageio

# %% [markdown]
# ## Create the Gym env and instantiate the agent
#
# For this example, we will be using the parking environment from the [highway-env](https://github.com/Farama-Foundation/HighwayEnv) repo by @eleurent.
#
# The parking env is a goal-conditioned continuous control task, in which the vehicle must park in a given space with the appropriate heading.
#
#
# ![parking-env](https://raw.githubusercontent.com/eleurent/highway-env/gh-media/docs/media/parking-env.gif)

# %% [markdown]
# ### Train Soft Actor-Critic (SAC) agent
#
# Here, we use HER "future" goal sampling strategy, where we create 4 artificial transitions per real transition
#
# Note: the hyperparameters (network architecture, discount factor, ...) were tuned for this task

# %%
env = gym.make("parking-v0")

# %%
# SAC hyperparams:
model = SAC(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future",
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_rate=1e-3,
    gamma=0.95,
    batch_size=256,
    policy_kwargs=dict(net_arch=[256, 256, 256]),
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train for 1e5 steps
model.learn(int(1e5))
# Save the trained agent
model.save('her_sac_highway')
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89       |
# |    ep_rew_mean     | -52.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 10       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 356      |
# | train/             |          |
# |    actor_loss      | -2.47    |
# |    critic_loss     | 0.0573   |
# |    ent_coef        | 0.776    |
# |    ent_coef_loss   | -0.861   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 255      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -47.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 10       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 650      |
# | train/             |          |
# |    actor_loss      | -2.46    |
# |    critic_loss     | 0.0462   |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | -1.84    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 549      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.6     |
# |    ep_rew_mean     | -41.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 9        |
# |    time_elapsed    | 94       |
# |    total_timesteps | 895      |
# | train/             |          |
# |    actor_loss      | -2.37    |
# |    critic_loss     | 0.201    |
# |    ent_coef        | 0.453    |
# |    ent_coef_loss   | -2.66    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 794      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.2     |
# |    ep_rew_mean     | -44.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 12       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 1331     |
# | train/             |          |
# |    actor_loss      | -2.07    |
# |    critic_loss     | 0.0325   |
# |    ent_coef        | 0.293    |
# |    ent_coef_loss   | -4.08    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1230     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | -65.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 16       |
# |    time_elapsed    | 145      |
# |    total_timesteps | 2445     |
# | train/             |          |
# |    actor_loss      | -0.685   |
# |    critic_loss     | 0.036    |
# |    ent_coef        | 0.098    |
# |    ent_coef_loss   | -7.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2344     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | -87.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 20       |
# |    time_elapsed    | 198      |
# |    total_timesteps | 4097     |
# | train/             |          |
# |    actor_loss      | 0.986    |
# |    critic_loss     | 0.00599  |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | -9.95    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3996     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | -99.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 23       |
# |    time_elapsed    | 261      |
# |    total_timesteps | 6097     |
# | train/             |          |
# |    actor_loss      | 1.89     |
# |    critic_loss     | 0.00534  |
# |    ent_coef        | 0.00569  |
# |    ent_coef_loss   | -3.78    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5996     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | -98.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 24       |
# |    time_elapsed    | 296      |
# |    total_timesteps | 7132     |
# | train/             |          |
# |    actor_loss      | 2.18     |
# |    critic_loss     | 0.00493  |
# |    ent_coef        | 0.00432  |
# |    ent_coef_loss   | 0.54     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7031     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | -89.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 24       |
# |    time_elapsed    | 300      |
# |    total_timesteps | 7251     |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.0151   |
# |    ent_coef        | 0.00432  |
# |    ent_coef_loss   | 0.0971   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7150     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | -83.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 24       |
# |    time_elapsed    | 309      |
# |    total_timesteps | 7554     |
# | train/             |          |
# |    actor_loss      | 2.37     |
# |    critic_loss     | 0.0315   |
# |    ent_coef        | 0.0041   |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7453     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | -77.4    |
# |    success_rate    | 0.0455   |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 24       |
# |    time_elapsed    | 313      |
# |    total_timesteps | 7655     |
# | train/             |          |
# |    actor_loss      | 2.19     |
# |    critic_loss     | 0.00545  |
# |    ent_coef        | 0.00402  |
# |    ent_coef_loss   | -1.95    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7554     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 164      |
# |    ep_rew_mean     | -73      |
# |    success_rate    | 0.0417   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 24       |
# |    time_elapsed    | 320      |
# |    total_timesteps | 7884     |
# | train/             |          |
# |    actor_loss      | 2.42     |
# |    critic_loss     | 0.00637  |
# |    ent_coef        | 0.0039   |
# |    ent_coef_loss   | -1.47    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7783     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 154      |
# |    ep_rew_mean     | -68.9    |
# |    success_rate    | 0.0385   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 24       |
# |    time_elapsed    | 324      |
# |    total_timesteps | 8016     |
# | train/             |          |
# |    actor_loss      | 2.42     |
# |    critic_loss     | 0.012    |
# |    ent_coef        | 0.00381  |
# |    ent_coef_loss   | 1.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7915     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 148      |
# |    ep_rew_mean     | -66.1    |
# |    success_rate    | 0.0536   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 24       |
# |    time_elapsed    | 333      |
# |    total_timesteps | 8309     |
# | train/             |          |
# |    actor_loss      | 2.4      |
# |    critic_loss     | 0.0078   |
# |    ent_coef        | 0.00376  |
# |    ent_coef_loss   | 0.327    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8208     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 148      |
# |    ep_rew_mean     | -64.6    |
# |    success_rate    | 0.0667   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 24       |
# |    time_elapsed    | 359      |
# |    total_timesteps | 8882     |
# | train/             |          |
# |    actor_loss      | 2.41     |
# |    critic_loss     | 0.00769  |
# |    ent_coef        | 0.00401  |
# |    ent_coef_loss   | -1.24    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8781     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -61.4    |
# |    success_rate    | 0.0781   |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 24       |
# |    time_elapsed    | 365      |
# |    total_timesteps | 9030     |
# | train/             |          |
# |    actor_loss      | 2.7      |
# |    critic_loss     | 0.011    |
# |    ent_coef        | 0.00403  |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8929     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 135      |
# |    ep_rew_mean     | -58.6    |
# |    success_rate    | 0.0882   |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 24       |
# |    time_elapsed    | 370      |
# |    total_timesteps | 9167     |
# | train/             |          |
# |    actor_loss      | 2.64     |
# |    critic_loss     | 0.00575  |
# |    ent_coef        | 0.0042   |
# |    ent_coef_loss   | 0.0859   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9066     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | -56.4    |
# |    success_rate    | 0.0833   |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 24       |
# |    time_elapsed    | 375      |
# |    total_timesteps | 9297     |
# | train/             |          |
# |    actor_loss      | 2.77     |
# |    critic_loss     | 0.0567   |
# |    ent_coef        | 0.00428  |
# |    ent_coef_loss   | 1.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9196     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | -55.4    |
# |    success_rate    | 0.0789   |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 24       |
# |    time_elapsed    | 398      |
# |    total_timesteps | 9895     |
# | train/             |          |
# |    actor_loss      | 2.45     |
# |    critic_loss     | 0.0116   |
# |    ent_coef        | 0.00422  |
# |    ent_coef_loss   | 0.545    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9794     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -53.7    |
# |    success_rate    | 0.075    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 24       |
# |    time_elapsed    | 403      |
# |    total_timesteps | 10031    |
# | train/             |          |
# |    actor_loss      | 2.52     |
# |    critic_loss     | 0.0168   |
# |    ent_coef        | 0.00414  |
# |    ent_coef_loss   | 0.137    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9930     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -51.9    |
# |    success_rate    | 0.0714   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 24       |
# |    time_elapsed    | 407      |
# |    total_timesteps | 10132    |
# | train/             |          |
# |    actor_loss      | 2.57     |
# |    critic_loss     | 0.00638  |
# |    ent_coef        | 0.00419  |
# |    ent_coef_loss   | -0.983   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10031    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | -51.6    |
# |    success_rate    | 0.0682   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 24       |
# |    time_elapsed    | 436      |
# |    total_timesteps | 10900    |
# | train/             |          |
# |    actor_loss      | 2.58     |
# |    critic_loss     | 0.00935  |
# |    ent_coef        | 0.00358  |
# |    ent_coef_loss   | 0.992    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -51.4    |
# |    success_rate    | 0.0652   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 25       |
# |    time_elapsed    | 460      |
# |    total_timesteps | 11529    |
# | train/             |          |
# |    actor_loss      | 2.42     |
# |    critic_loss     | 0.00513  |
# |    ent_coef        | 0.0038   |
# |    ent_coef_loss   | -0.981   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -49.8    |
# |    success_rate    | 0.0729   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 25       |
# |    time_elapsed    | 465      |
# |    total_timesteps | 11634    |
# | train/             |          |
# |    actor_loss      | 2.51     |
# |    critic_loss     | 0.0169   |
# |    ent_coef        | 0.00385  |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11533    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | -49.4    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 25       |
# |    time_elapsed    | 487      |
# |    total_timesteps | 12210    |
# | train/             |          |
# |    actor_loss      | 2.54     |
# |    critic_loss     | 0.0054   |
# |    ent_coef        | 0.00394  |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12109    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 24       |
# |    time_elapsed    | 516      |
# |    total_timesteps | 12847    |
# | train/             |          |
# |    actor_loss      | 2.55     |
# |    critic_loss     | 0.00665  |
# |    ent_coef        | 0.00374  |
# |    ent_coef_loss   | 0.0607   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12746    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 132      |
# |    ep_rew_mean     | -49.6    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 24       |
# |    time_elapsed    | 560      |
# |    total_timesteps | 13894    |
# | train/             |          |
# |    actor_loss      | 2.47     |
# |    critic_loss     | 0.00481  |
# |    ent_coef        | 0.0033   |
# |    ent_coef_loss   | 0.572    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13793    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -50.7    |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 24       |
# |    time_elapsed    | 608      |
# |    total_timesteps | 15081    |
# | train/             |          |
# |    actor_loss      | 2.29     |
# |    critic_loss     | 0.00909  |
# |    ent_coef        | 0.00305  |
# |    ent_coef_loss   | -0.426   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14980    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | -49.1    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 24       |
# |    time_elapsed    | 612      |
# |    total_timesteps | 15176    |
# | train/             |          |
# |    actor_loss      | 2.36     |
# |    critic_loss     | 0.00588  |
# |    ent_coef        | 0.00298  |
# |    ent_coef_loss   | -0.721   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15075    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -44.4    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 24       |
# |    time_elapsed    | 637      |
# |    total_timesteps | 15742    |
# | train/             |          |
# |    actor_loss      | 2.29     |
# |    critic_loss     | 0.00617  |
# |    ent_coef        | 0.00313  |
# |    ent_coef_loss   | -1.99    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15641    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | -38.7    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 24       |
# |    time_elapsed    | 678      |
# |    total_timesteps | 16791    |
# | train/             |          |
# |    actor_loss      | 2.36     |
# |    critic_loss     | 0.0042   |
# |    ent_coef        | 0.00334  |
# |    ent_coef_loss   | 0.308    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16690    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 115      |
# |    ep_rew_mean     | -33.3    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 24       |
# |    time_elapsed    | 708      |
# |    total_timesteps | 17579    |
# | train/             |          |
# |    actor_loss      | 2.07     |
# |    critic_loss     | 0.00481  |
# |    ent_coef        | 0.00335  |
# |    ent_coef_loss   | -1.24    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17478    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 115      |
# |    ep_rew_mean     | -31.8    |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 24       |
# |    time_elapsed    | 755      |
# |    total_timesteps | 18665    |
# | train/             |          |
# |    actor_loss      | 2.24     |
# |    critic_loss     | 0.00448  |
# |    ent_coef        | 0.00315  |
# |    ent_coef_loss   | 1.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18564    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -31.9    |
# |    success_rate    | 0.16     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 24       |
# |    time_elapsed    | 771      |
# |    total_timesteps | 19064    |
# | train/             |          |
# |    actor_loss      | 2.21     |
# |    critic_loss     | 0.00524  |
# |    ent_coef        | 0.00318  |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18963    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -31.6    |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 24       |
# |    time_elapsed    | 787      |
# |    total_timesteps | 19463    |
# | train/             |          |
# |    actor_loss      | 2.2      |
# |    critic_loss     | 0.00383  |
# |    ent_coef        | 0.00311  |
# |    ent_coef_loss   | -0.548   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19362    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | -32.2    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 24       |
# |    time_elapsed    | 809      |
# |    total_timesteps | 20023    |
# | train/             |          |
# |    actor_loss      | 2.23     |
# |    critic_loss     | 0.00514  |
# |    ent_coef        | 0.00307  |
# |    ent_coef_loss   | 0.394    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19922    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -33.9    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 24       |
# |    time_elapsed    | 870      |
# |    total_timesteps | 21510    |
# | train/             |          |
# |    actor_loss      | 2.07     |
# |    critic_loss     | 0.00544  |
# |    ent_coef        | 0.00285  |
# |    ent_coef_loss   | 0.139    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21409    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -34.2    |
# |    success_rate    | 0.21     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 24       |
# |    time_elapsed    | 893      |
# |    total_timesteps | 22069    |
# | train/             |          |
# |    actor_loss      | 1.93     |
# |    critic_loss     | 0.00383  |
# |    ent_coef        | 0.00281  |
# |    ent_coef_loss   | -1.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21968    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | -34.1    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 24       |
# |    time_elapsed    | 915      |
# |    total_timesteps | 22642    |
# | train/             |          |
# |    actor_loss      | 2.07     |
# |    critic_loss     | 0.00365  |
# |    ent_coef        | 0.00279  |
# |    ent_coef_loss   | -0.531   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22541    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0.22     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 24       |
# |    time_elapsed    | 921      |
# |    total_timesteps | 22795    |
# | train/             |          |
# |    actor_loss      | 2.02     |
# |    critic_loss     | 0.00509  |
# |    ent_coef        | 0.00276  |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22694    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | -32.7    |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 24       |
# |    time_elapsed    | 925      |
# |    total_timesteps | 22890    |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.00526  |
# |    ent_coef        | 0.00269  |
# |    ent_coef_loss   | 0.401    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22789    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | -32.6    |
# |    success_rate    | 0.24     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 24       |
# |    time_elapsed    | 931      |
# |    total_timesteps | 23052    |
# | train/             |          |
# |    actor_loss      | 1.9      |
# |    critic_loss     | 0.00702  |
# |    ent_coef        | 0.00264  |
# |    ent_coef_loss   | -2.48    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22951    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | -32.4    |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 24       |
# |    time_elapsed    | 935      |
# |    total_timesteps | 23167    |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.00871  |
# |    ent_coef        | 0.00265  |
# |    ent_coef_loss   | -0.59    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23066    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | -32.9    |
# |    success_rate    | 0.25     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 24       |
# |    time_elapsed    | 977      |
# |    total_timesteps | 24205    |
# | train/             |          |
# |    actor_loss      | 1.94     |
# |    critic_loss     | 0.00442  |
# |    ent_coef        | 0.00255  |
# |    ent_coef_loss   | 0.531    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24104    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -32.6    |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 24       |
# |    time_elapsed    | 984      |
# |    total_timesteps | 24383    |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 0.00557  |
# |    ent_coef        | 0.00259  |
# |    ent_coef_loss   | -0.666   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24282    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -32.4    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 24       |
# |    time_elapsed    | 991      |
# |    total_timesteps | 24565    |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.00352  |
# |    ent_coef        | 0.00255  |
# |    ent_coef_loss   | 0.663    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24464    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | -31.3    |
# |    success_rate    | 0.33     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 24       |
# |    time_elapsed    | 1002     |
# |    total_timesteps | 24861    |
# | train/             |          |
# |    actor_loss      | 1.99     |
# |    critic_loss     | 0.0053   |
# |    ent_coef        | 0.00259  |
# |    ent_coef_loss   | 1.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24760    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 134      |
# |    ep_rew_mean     | -29.9    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 24       |
# |    time_elapsed    | 1006     |
# |    total_timesteps | 24959    |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 0.00409  |
# |    ent_coef        | 0.00261  |
# |    ent_coef_loss   | 0.859    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24858    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | -30.6    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 23       |
# |    time_elapsed    | 1073     |
# |    total_timesteps | 25540    |
# | train/             |          |
# |    actor_loss      | 2.02     |
# |    critic_loss     | 0.00679  |
# |    ent_coef        | 0.00255  |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25439    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | -30.1    |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 23       |
# |    time_elapsed    | 1134     |
# |    total_timesteps | 26111    |
# | train/             |          |
# |    actor_loss      | 1.98     |
# |    critic_loss     | 0.00939  |
# |    ent_coef        | 0.00253  |
# |    ent_coef_loss   | -0.942   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26010    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | -29.4    |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 22       |
# |    time_elapsed    | 1196     |
# |    total_timesteps | 26675    |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.0053   |
# |    ent_coef        | 0.00252  |
# |    ent_coef_loss   | -0.944   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26574    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | -27.5    |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 22       |
# |    time_elapsed    | 1208     |
# |    total_timesteps | 26797    |
# | train/             |          |
# |    actor_loss      | 1.99     |
# |    critic_loss     | 0.00436  |
# |    ent_coef        | 0.00244  |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26696    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -26.2    |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 21       |
# |    time_elapsed    | 1273     |
# |    total_timesteps | 27359    |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.00349  |
# |    ent_coef        | 0.00243  |
# |    ent_coef_loss   | 1.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27258    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -26      |
# |    success_rate    | 0.46     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 21       |
# |    time_elapsed    | 1285     |
# |    total_timesteps | 27459    |
# | train/             |          |
# |    actor_loss      | 2.01     |
# |    critic_loss     | 0.0079   |
# |    ent_coef        | 0.00252  |
# |    ent_coef_loss   | 1.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27358    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -25      |
# |    success_rate    | 0.5      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 21       |
# |    time_elapsed    | 1295     |
# |    total_timesteps | 27547    |
# | train/             |          |
# |    actor_loss      | 1.98     |
# |    critic_loss     | 0.00344  |
# |    ent_coef        | 0.00252  |
# |    ent_coef_loss   | 0.393    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27446    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | -23.3    |
# |    success_rate    | 0.52     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 21       |
# |    time_elapsed    | 1305     |
# |    total_timesteps | 27654    |
# | train/             |          |
# |    actor_loss      | 1.89     |
# |    critic_loss     | 0.00743  |
# |    ent_coef        | 0.00251  |
# |    ent_coef_loss   | -0.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27553    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0.52     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 20       |
# |    time_elapsed    | 1360     |
# |    total_timesteps | 28225    |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 0.00452  |
# |    ent_coef        | 0.00248  |
# |    ent_coef_loss   | 0.661    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28124    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.6     |
# |    ep_rew_mean     | -21.3    |
# |    success_rate    | 0.53     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 20       |
# |    time_elapsed    | 1389     |
# |    total_timesteps | 28523    |
# | train/             |          |
# |    actor_loss      | 1.79     |
# |    critic_loss     | 0.00615  |
# |    ent_coef        | 0.00233  |
# |    ent_coef_loss   | -1.74    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28422    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.9     |
# |    ep_rew_mean     | -21.1    |
# |    success_rate    | 0.55     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 20       |
# |    time_elapsed    | 1426     |
# |    total_timesteps | 28851    |
# | train/             |          |
# |    actor_loss      | 1.84     |
# |    critic_loss     | 0.00582  |
# |    ent_coef        | 0.00243  |
# |    ent_coef_loss   | -0.0963  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28750    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.5     |
# |    ep_rew_mean     | -21.1    |
# |    success_rate    | 0.56     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 19       |
# |    time_elapsed    | 1463     |
# |    total_timesteps | 29218    |
# | train/             |          |
# |    actor_loss      | 1.93     |
# |    critic_loss     | 0.00786  |
# |    ent_coef        | 0.00236  |
# |    ent_coef_loss   | -0.651   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29117    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.1     |
# |    ep_rew_mean     | -20.7    |
# |    success_rate    | 0.58     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 19       |
# |    time_elapsed    | 1518     |
# |    total_timesteps | 29729    |
# | train/             |          |
# |    actor_loss      | 1.89     |
# |    critic_loss     | 0.00559  |
# |    ent_coef        | 0.00241  |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29628    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.1     |
# |    ep_rew_mean     | -18.6    |
# |    success_rate    | 0.59     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 19       |
# |    time_elapsed    | 1538     |
# |    total_timesteps | 29917    |
# | train/             |          |
# |    actor_loss      | 2        |
# |    critic_loss     | 0.0118   |
# |    ent_coef        | 0.00249  |
# |    ent_coef_loss   | 1.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29816    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.4     |
# |    ep_rew_mean     | -17.8    |
# |    success_rate    | 0.61     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 19       |
# |    time_elapsed    | 1549     |
# |    total_timesteps | 30011    |
# | train/             |          |
# |    actor_loss      | 1.88     |
# |    critic_loss     | 0.00557  |
# |    ent_coef        | 0.00248  |
# |    ent_coef_loss   | -0.639   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29910    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.5     |
# |    ep_rew_mean     | -17.1    |
# |    success_rate    | 0.63     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 19       |
# |    time_elapsed    | 1556     |
# |    total_timesteps | 30095    |
# | train/             |          |
# |    actor_loss      | 1.78     |
# |    critic_loss     | 0.00444  |
# |    ent_coef        | 0.00239  |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29994    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.3     |
# |    ep_rew_mean     | -17.1    |
# |    success_rate    | 0.63     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 19       |
# |    time_elapsed    | 1561     |
# |    total_timesteps | 30228    |
# | train/             |          |
# |    actor_loss      | 1.85     |
# |    critic_loss     | 0.00571  |
# |    ent_coef        | 0.00252  |
# |    ent_coef_loss   | 0.753    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30127    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76       |
# |    ep_rew_mean     | -17.2    |
# |    success_rate    | 0.63     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 19       |
# |    time_elapsed    | 1570     |
# |    total_timesteps | 30488    |
# | train/             |          |
# |    actor_loss      | 1.8      |
# |    critic_loss     | 0.00403  |
# |    ent_coef        | 0.00244  |
# |    ent_coef_loss   | 0.131    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30387    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.1     |
# |    ep_rew_mean     | -17      |
# |    success_rate    | 0.65     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 19       |
# |    time_elapsed    | 1573     |
# |    total_timesteps | 30561    |
# | train/             |          |
# |    actor_loss      | 1.89     |
# |    critic_loss     | 0.00861  |
# |    ent_coef        | 0.00248  |
# |    ent_coef_loss   | 0.518    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30460    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.2     |
# |    ep_rew_mean     | -17      |
# |    success_rate    | 0.67     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 19       |
# |    time_elapsed    | 1581     |
# |    total_timesteps | 30786    |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 0.00569  |
# |    ent_coef        | 0.00233  |
# |    ent_coef_loss   | 0.692    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30685    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 67.1     |
# |    ep_rew_mean     | -15.5    |
# |    success_rate    | 0.69     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 19       |
# |    time_elapsed    | 1585     |
# |    total_timesteps | 30914    |
# | train/             |          |
# |    actor_loss      | 1.96     |
# |    critic_loss     | 0.00773  |
# |    ent_coef        | 0.00243  |
# |    ent_coef_loss   | -0.771   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30813    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.2     |
# |    ep_rew_mean     | -15.3    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 19       |
# |    time_elapsed    | 1588     |
# |    total_timesteps | 31002    |
# | train/             |          |
# |    actor_loss      | 1.85     |
# |    critic_loss     | 0.00771  |
# |    ent_coef        | 0.00243  |
# |    ent_coef_loss   | -3.41    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30901    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66       |
# |    ep_rew_mean     | -15.2    |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 19       |
# |    time_elapsed    | 1594     |
# |    total_timesteps | 31163    |
# | train/             |          |
# |    actor_loss      | 1.74     |
# |    critic_loss     | 0.00699  |
# |    ent_coef        | 0.00245  |
# |    ent_coef_loss   | -0.915   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31062    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.9     |
# |    ep_rew_mean     | -14.7    |
# |    success_rate    | 0.71     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 19       |
# |    time_elapsed    | 1596     |
# |    total_timesteps | 31248    |
# | train/             |          |
# |    actor_loss      | 1.89     |
# |    critic_loss     | 0.00481  |
# |    ent_coef        | 0.00252  |
# |    ent_coef_loss   | 2.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31147    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.9     |
# |    ep_rew_mean     | -14.6    |
# |    success_rate    | 0.72     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 19       |
# |    time_elapsed    | 1600     |
# |    total_timesteps | 31349    |
# | train/             |          |
# |    actor_loss      | 1.82     |
# |    critic_loss     | 0.00593  |
# |    ent_coef        | 0.00258  |
# |    ent_coef_loss   | -0.482   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31248    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.1     |
# |    ep_rew_mean     | -14      |
# |    success_rate    | 0.7      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 19       |
# |    time_elapsed    | 1603     |
# |    total_timesteps | 31451    |
# | train/             |          |
# |    actor_loss      | 1.78     |
# |    critic_loss     | 0.00639  |
# |    ent_coef        | 0.00268  |
# |    ent_coef_loss   | 0.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31350    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.4     |
# |    ep_rew_mean     | -13.1    |
# |    success_rate    | 0.73     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 19       |
# |    time_elapsed    | 1606     |
# |    total_timesteps | 31547    |
# | train/             |          |
# |    actor_loss      | 1.89     |
# |    critic_loss     | 0.0112   |
# |    ent_coef        | 0.00261  |
# |    ent_coef_loss   | 0.531    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31446    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.7     |
# |    ep_rew_mean     | -12.5    |
# |    success_rate    | 0.74     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 19       |
# |    time_elapsed    | 1609     |
# |    total_timesteps | 31644    |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.00569  |
# |    ent_coef        | 0.0026   |
# |    ent_coef_loss   | -1.37    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31543    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.3     |
# |    ep_rew_mean     | -13.3    |
# |    success_rate    | 0.73     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 19       |
# |    time_elapsed    | 1629     |
# |    total_timesteps | 32230    |
# | train/             |          |
# |    actor_loss      | 1.91     |
# |    critic_loss     | 0.00551  |
# |    ent_coef        | 0.00248  |
# |    ent_coef_loss   | 0.794    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 32129    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.6     |
# |    ep_rew_mean     | -12.5    |
# |    success_rate    | 0.75     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 19       |
# |    time_elapsed    | 1632     |
# |    total_timesteps | 32317    |
# | train/             |          |
# |    actor_loss      | 1.81     |
# |    critic_loss     | 0.00604  |
# |    ent_coef        | 0.0025   |
# |    ent_coef_loss   | 0.105    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 32216    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | -12.5    |
# |    success_rate    | 0.75     |
# | time/              |          |
# |    episodes        | 316      |
# ...
# |    n_updates       | 97819    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.9     |
# |    ep_rew_mean     | -6.86    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3260     |
# |    fps             | 18       |
# |    time_elapsed    | 5357     |
# |    total_timesteps | 97981    |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.00547  |
# |    ent_coef        | 0.00526  |
# |    ent_coef_loss   | -0.278   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97880    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.1     |
# |    ep_rew_mean     | -7.02    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3264     |
# |    fps             | 18       |
# |    time_elapsed    | 5369     |
# |    total_timesteps | 98079    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00497  |
# |    ent_coef        | 0.00532  |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97978    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.1     |
# |    ep_rew_mean     | -6.99    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3268     |
# |    fps             | 18       |
# |    time_elapsed    | 5383     |
# |    total_timesteps | 98179    |
# | train/             |          |
# |    actor_loss      | 1.72     |
# |    critic_loss     | 0.0103   |
# |    ent_coef        | 0.00527  |
# |    ent_coef_loss   | 0.229    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98078    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.2     |
# |    ep_rew_mean     | -7.04    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3272     |
# |    fps             | 18       |
# |    time_elapsed    | 5386     |
# |    total_timesteps | 98253    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00413  |
# |    ent_coef        | 0.0053   |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98152    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | -7.15    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3276     |
# |    fps             | 18       |
# |    time_elapsed    | 5390     |
# |    total_timesteps | 98349    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.0209   |
# |    ent_coef        | 0.00533  |
# |    ent_coef_loss   | 0.473    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98248    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.3     |
# |    ep_rew_mean     | -7.08    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3280     |
# |    fps             | 18       |
# |    time_elapsed    | 5392     |
# |    total_timesteps | 98408    |
# | train/             |          |
# |    actor_loss      | 1.71     |
# |    critic_loss     | 0.0586   |
# |    ent_coef        | 0.00532  |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98307    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | -7.15    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3284     |
# |    fps             | 18       |
# |    time_elapsed    | 5401     |
# |    total_timesteps | 98482    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.0155   |
# |    ent_coef        | 0.00525  |
# |    ent_coef_loss   | 0.167    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98381    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | -7.1     |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 3288     |
# |    fps             | 18       |
# |    time_elapsed    | 5413     |
# |    total_timesteps | 98565    |
# | train/             |          |
# |    actor_loss      | 1.48     |
# |    critic_loss     | 0.0186   |
# |    ent_coef        | 0.00533  |
# |    ent_coef_loss   | -1.52    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98464    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | -7.08    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3292     |
# |    fps             | 18       |
# |    time_elapsed    | 5429     |
# |    total_timesteps | 98659    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.0074   |
# |    ent_coef        | 0.00531  |
# |    ent_coef_loss   | -2.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98558    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | -7.08    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3296     |
# |    fps             | 18       |
# |    time_elapsed    | 5441     |
# |    total_timesteps | 98740    |
# | train/             |          |
# |    actor_loss      | 1.48     |
# |    critic_loss     | 0.00922  |
# |    ent_coef        | 0.00517  |
# |    ent_coef_loss   | -0.146   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98639    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.2     |
# |    ep_rew_mean     | -6.95    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 18       |
# |    time_elapsed    | 5452     |
# |    total_timesteps | 98811    |
# | train/             |          |
# |    actor_loss      | 1.76     |
# |    critic_loss     | 0.00579  |
# |    ent_coef        | 0.00516  |
# |    ent_coef_loss   | 0.965    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98710    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | -7.06    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3304     |
# |    fps             | 18       |
# |    time_elapsed    | 5465     |
# |    total_timesteps | 98899    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.0221   |
# |    ent_coef        | 0.0052   |
# |    ent_coef_loss   | 0.917    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98798    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.3     |
# |    ep_rew_mean     | -7.01    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3308     |
# |    fps             | 18       |
# |    time_elapsed    | 5476     |
# |    total_timesteps | 98973    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00608  |
# |    ent_coef        | 0.00513  |
# |    ent_coef_loss   | -0.421   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98872    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | -7.12    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3312     |
# |    fps             | 18       |
# |    time_elapsed    | 5487     |
# |    total_timesteps | 99062    |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.01     |
# |    ent_coef        | 0.00514  |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98961    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | -7.04    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3316     |
# |    fps             | 18       |
# |    time_elapsed    | 5489     |
# |    total_timesteps | 99133    |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.0118   |
# |    ent_coef        | 0.00519  |
# |    ent_coef_loss   | -0.544   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99032    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | -7.17    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3320     |
# |    fps             | 18       |
# |    time_elapsed    | 5493     |
# |    total_timesteps | 99213    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.0051   |
# |    ent_coef        | 0.00525  |
# |    ent_coef_loss   | -0.242   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99112    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | -7.17    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3324     |
# |    fps             | 18       |
# |    time_elapsed    | 5496     |
# |    total_timesteps | 99291    |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.00934  |
# |    ent_coef        | 0.00524  |
# |    ent_coef_loss   | -0.907   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.8     |
# |    ep_rew_mean     | -7.3     |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3328     |
# |    fps             | 18       |
# |    time_elapsed    | 5504     |
# |    total_timesteps | 99358    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.00743  |
# |    ent_coef        | 0.00524  |
# |    ent_coef_loss   | 0.524    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99257    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3332     |
# |    fps             | 18       |
# |    time_elapsed    | 5511     |
# |    total_timesteps | 99412    |
# | train/             |          |
# |    actor_loss      | 1.84     |
# |    critic_loss     | 0.00856  |
# |    ent_coef        | 0.00528  |
# |    ent_coef_loss   | 1.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99311    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | -7.06    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 3336     |
# |    fps             | 18       |
# |    time_elapsed    | 5518     |
# |    total_timesteps | 99470    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00577  |
# |    ent_coef        | 0.00532  |
# |    ent_coef_loss   | -0.0801  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99369    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | -7.02    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3340     |
# |    fps             | 18       |
# |    time_elapsed    | 5529     |
# |    total_timesteps | 99554    |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.0525   |
# |    ent_coef        | 0.00538  |
# |    ent_coef_loss   | -0.907   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99453    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | -6.97    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3344     |
# |    fps             | 17       |
# |    time_elapsed    | 5540     |
# |    total_timesteps | 99626    |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.00528  |
# |    ent_coef        | 0.00535  |
# |    ent_coef_loss   | -0.407   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99525    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | -6.99    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3348     |
# |    fps             | 17       |
# |    time_elapsed    | 5554     |
# |    total_timesteps | 99705    |
# | train/             |          |
# |    actor_loss      | 1.62     |
# |    critic_loss     | 0.0136   |
# |    ent_coef        | 0.00535  |
# |    ent_coef_loss   | 0.618    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99604    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | -7.05    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3352     |
# |    fps             | 17       |
# |    time_elapsed    | 5568     |
# |    total_timesteps | 99780    |
# | train/             |          |
# |    actor_loss      | 1.73     |
# |    critic_loss     | 0.0154   |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | 1.55     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99679    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | -7.12    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 3356     |
# |    fps             | 17       |
# |    time_elapsed    | 5577     |
# |    total_timesteps | 99857    |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.00759  |
# |    ent_coef        | 0.0055   |
# |    ent_coef_loss   | -0.0232  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99756    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.4     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3360     |
# |    fps             | 17       |
# |    time_elapsed    | 5586     |
# |    total_timesteps | 99921    |
# | train/             |          |
# |    actor_loss      | 1.67     |
# |    critic_loss     | 0.0193   |
# |    ent_coef        | 0.00551  |
# |    ent_coef_loss   | 0.581    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99820    |
# ---------------------------------

# %%
# Load saved model
model = SAC.load('her_sac_highway', env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# #### Evaluate SAC agent

# %%
# we use the gym >v.26 API here. Note that you could also wrap the env in a DummyVecEnv
# which allows you to use a simplified API
obs, _ = env.reset()

# Evaluate the agent
episode_reward = 0
for _ in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = truncated or terminated
    episode_reward += reward
    if done or info.get("is_success", False):
        print("Reward:", episode_reward, "Success?", info.get("is_success", False))
        episode_reward = 0.0
        obs, _ = env.reset()
# Out:
# Reward: -13.220677567305547 Success? False
# Reward: -12.489266528126073 Success? False
# Reward: -6.312339707254436 Success? True
# Reward: -5.989705652621492 Success? True
# Reward: -14.453279608260836 Success? False
# Reward: -9.729581976657908 Success? True
# Reward: -7.401599480443453 Success? True
# Reward: -11.037402987219409 Success? True
# Reward: -3.1743355432581586 Success? True
# Reward: -3.5783419868026614 Success? True
# Reward: -3.3315189380794026 Success? True
# Reward: -6.57567094880589 Success? True
# Reward: -8.735434387996053 Success? True
# Reward: -4.520352591625949 Success? True
# Reward: -10.839384820143952 Success? False
# Reward: -3.1086932440667376 Success? True
# Reward: -11.491171472721291 Success? False
# Reward: -6.462331375395717 Success? True
# Reward: -5.513745468769035 Success? True
# Reward: -5.294821258521379 Success? True
# Reward: -5.346307176079068 Success? True
# Reward: -4.353214644771106 Success? True
# Reward: -5.041152246562712 Success? True
# Reward: -4.369845515097199 Success? True
# Reward: -4.213540835444843 Success? True
# Reward: -8.064369939950852 Success? True
# Reward: -3.3043299443369976 Success? True
# Reward: -12.130624298632668 Success? False
# Reward: -15.15874238451722 Success? False
# Reward: -4.1524891393201235 Success? True
# Reward: -2.5742124056775144 Success? True
# Reward: -4.5097960187015955 Success? True
# Reward: -2.4057801660851243 Success? True
# Reward: -6.340200906162435 Success? True
# Reward: -14.256618220541192 Success? False
# Reward: -8.902542699931045 Success? True
# Reward: -5.494926265891888 Success? True
# Reward: -10.808166520361555 Success? False
# Reward: -4.536249471571548 Success? True
# Reward: -10.42015119111117 Success? True
# Reward: -4.495826045564008 Success? True
# Reward: -5.233769652322819 Success? True
# Reward: -4.585432772198073 Success? True
# Reward: -11.837223814867532 Success? True
# Reward: -6.60135138528671 Success? True
# Reward: -9.88283242332657 Success? True
# Reward: -4.560982570696156 Success? True
# Reward: -5.204835108138995 Success? True
# Reward: -6.45380389743124 Success? True
# Reward: -2.6161160363354186 Success? True
# Reward: -6.35346322872964 Success? True
# Reward: -3.4866267845891774 Success? True
# Reward: -6.303160468977364 Success? True

# %% [markdown]
# ### Train DDPG agent

# %%
# Create the action noise object that will be used for exploration
n_actions = env.action_space.shape[0]
noise_std = 0.2
action_noise = NormalActionNoise(
    mean=np.zeros(n_actions), sigma=noise_std * np.ones(n_actions)
)

model = DDPG(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future",
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_rate=1e-3,
    action_noise=action_noise,
    gamma=0.95,
    batch_size=256,
    policy_kwargs=dict(net_arch=[256, 256, 256]),
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train for 2e5 steps
model.learn(int(2e5))
# Save the trained agent
model.save('her_ddpg_highway')
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 173      |
# |    ep_rew_mean     | -87.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 53       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 693      |
# | train/             |          |
# |    actor_loss      | 1.28     |
# |    critic_loss     | 0.0345   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 592      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 242      |
# |    ep_rew_mean     | -118     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 43       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 1934     |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.0113   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1833     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 177      |
# |    ep_rew_mean     | -88.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 43       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 2125     |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.00871  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2024     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -70.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 42       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 2266     |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.00754  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2165     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | -64.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 34       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 2529     |
# | train/             |          |
# |    actor_loss      | 1.82     |
# |    critic_loss     | 0.045    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2428     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | -57.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 31       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 2664     |
# | train/             |          |
# |    actor_loss      | 1.83     |
# |    critic_loss     | 0.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2563     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -53.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 29       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 2814     |
# | train/             |          |
# |    actor_loss      | 1.85     |
# |    critic_loss     | 0.0101   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2713     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.5     |
# |    ep_rew_mean     | -49.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 27       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 2961     |
# | train/             |          |
# |    actor_loss      | 2.04     |
# |    critic_loss     | 0.0174   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2860     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.1     |
# |    ep_rew_mean     | -46      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 26       |
# |    time_elapsed    | 114      |
# |    total_timesteps | 3065     |
# | train/             |          |
# |    actor_loss      | 1.81     |
# |    critic_loss     | 0.0146   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2964     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.9     |
# |    ep_rew_mean     | -43.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 26       |
# |    time_elapsed    | 120      |
# |    total_timesteps | 3156     |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.00767  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3055     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.9     |
# |    ep_rew_mean     | -41      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 25       |
# |    time_elapsed    | 130      |
# |    total_timesteps | 3296     |
# | train/             |          |
# |    actor_loss      | 1.94     |
# |    critic_loss     | 0.0555   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3195     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.5     |
# |    ep_rew_mean     | -38.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 24       |
# |    time_elapsed    | 138      |
# |    total_timesteps | 3384     |
# | train/             |          |
# |    actor_loss      | 2        |
# |    critic_loss     | 0.0402   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3283     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 67.7     |
# |    ep_rew_mean     | -37.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 23       |
# |    time_elapsed    | 148      |
# |    total_timesteps | 3518     |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.0166   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3417     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.8     |
# |    ep_rew_mean     | -36.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 22       |
# |    time_elapsed    | 165      |
# |    total_timesteps | 3739     |
# | train/             |          |
# |    actor_loss      | 2.09     |
# |    critic_loss     | 0.0665   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3638     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 67.1     |
# |    ep_rew_mean     | -37      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 21       |
# |    time_elapsed    | 187      |
# |    total_timesteps | 4028     |
# | train/             |          |
# |    actor_loss      | 2.01     |
# |    critic_loss     | 0.0143   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3927     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.9     |
# |    ep_rew_mean     | -35.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 21       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 4151     |
# | train/             |          |
# |    actor_loss      | 2.01     |
# |    critic_loss     | 0.0324   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4050     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63       |
# |    ep_rew_mean     | -34.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 20       |
# |    time_elapsed    | 206      |
# |    total_timesteps | 4282     |
# | train/             |          |
# |    actor_loss      | 2.14     |
# |    critic_loss     | 0.0176   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4181     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.7     |
# |    ep_rew_mean     | -40.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 18       |
# |    time_elapsed    | 291      |
# |    total_timesteps | 5452     |
# | train/             |          |
# |    actor_loss      | 2.02     |
# |    critic_loss     | 0.0121   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5351     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.6     |
# |    ep_rew_mean     | -39      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 18       |
# |    time_elapsed    | 296      |
# |    total_timesteps | 5521     |
# | train/             |          |
# |    actor_loss      | 1.81     |
# |    critic_loss     | 0.0127   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5420     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71       |
# |    ep_rew_mean     | -38      |
# |    success_rate    | 0.0125   |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 18       |
# |    time_elapsed    | 309      |
# |    total_timesteps | 5678     |
# | train/             |          |
# |    actor_loss      | 1.87     |
# |    critic_loss     | 0.00955  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5577     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 69.5     |
# |    ep_rew_mean     | -37.4    |
# |    success_rate    | 0.0119   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 18       |
# |    time_elapsed    | 320      |
# |    total_timesteps | 5836     |
# | train/             |          |
# |    actor_loss      | 1.98     |
# |    critic_loss     | 0.0408   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5735     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 67.6     |
# |    ep_rew_mean     | -36.5    |
# |    success_rate    | 0.0114   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 18       |
# |    time_elapsed    | 328      |
# |    total_timesteps | 5951     |
# | train/             |          |
# |    actor_loss      | 1.88     |
# |    critic_loss     | 0.0172   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5850     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.5     |
# |    ep_rew_mean     | -35.8    |
# |    success_rate    | 0.0109   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 17       |
# |    time_elapsed    | 340      |
# |    total_timesteps | 6114     |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 0.0122   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6013     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.8     |
# |    ep_rew_mean     | -35      |
# |    success_rate    | 0.0104   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 17       |
# |    time_elapsed    | 348      |
# |    total_timesteps | 6222     |
# | train/             |          |
# |    actor_loss      | 1.93     |
# |    critic_loss     | 0.0116   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6121     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.4     |
# |    ep_rew_mean     | -34.3    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 17       |
# |    time_elapsed    | 357      |
# |    total_timesteps | 6337     |
# | train/             |          |
# |    actor_loss      | 1.89     |
# |    critic_loss     | 0.0189   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6236     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 58.7     |
# |    ep_rew_mean     | -32.1    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 17       |
# |    time_elapsed    | 373      |
# |    total_timesteps | 6567     |
# | train/             |          |
# |    actor_loss      | 1.93     |
# |    critic_loss     | 0.014    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6466     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.2     |
# |    ep_rew_mean     | -26.7    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 17       |
# |    time_elapsed    | 379      |
# |    total_timesteps | 6650     |
# | train/             |          |
# |    actor_loss      | 1.92     |
# |    critic_loss     | 0.0261   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6549     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46       |
# |    ep_rew_mean     | -26.1    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 17       |
# |    time_elapsed    | 385      |
# |    total_timesteps | 6728     |
# | train/             |          |
# |    actor_loss      | 2.05     |
# |    critic_loss     | 0.019    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6627     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | -26.3    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 17       |
# |    time_elapsed    | 397      |
# |    total_timesteps | 6927     |
# | train/             |          |
# |    actor_loss      | 2.02     |
# |    critic_loss     | 0.0143   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6826     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.8     |
# |    ep_rew_mean     | -25.2    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 17       |
# |    time_elapsed    | 399      |
# |    total_timesteps | 7007     |
# | train/             |          |
# |    actor_loss      | 1.86     |
# |    critic_loss     | 0.0112   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6906     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | -26.3    |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 17       |
# |    time_elapsed    | 424      |
# |    total_timesteps | 7417     |
# | train/             |          |
# |    actor_loss      | 1.84     |
# |    critic_loss     | 0.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7316     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.6     |
# |    ep_rew_mean     | -26.7    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 17       |
# |    time_elapsed    | 453      |
# |    total_timesteps | 7971     |
# | train/             |          |
# |    actor_loss      | 2.07     |
# |    critic_loss     | 0.0105   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7870     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.2     |
# |    ep_rew_mean     | -26.4    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 17       |
# |    time_elapsed    | 461      |
# |    total_timesteps | 8083     |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.0114   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7982     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.1     |
# |    ep_rew_mean     | -26.2    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 17       |
# |    time_elapsed    | 468      |
# |    total_timesteps | 8172     |
# | train/             |          |
# |    actor_loss      | 2.03     |
# |    critic_loss     | 0.00964  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8071     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.3     |
# |    ep_rew_mean     | -26.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 17       |
# |    time_elapsed    | 476      |
# |    total_timesteps | 8282     |
# | train/             |          |
# |    actor_loss      | 1.78     |
# |    critic_loss     | 0.0121   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8181     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.5     |
# |    ep_rew_mean     | -26.7    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 17       |
# |    time_elapsed    | 515      |
# |    total_timesteps | 8841     |
# | train/             |          |
# |    actor_loss      | 1.79     |
# |    critic_loss     | 0.00827  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8740     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.4     |
# |    ep_rew_mean     | -27      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 17       |
# |    time_elapsed    | 528      |
# |    total_timesteps | 9026     |
# | train/             |          |
# |    actor_loss      | 1.87     |
# |    critic_loss     | 0.0118   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8925     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.8     |
# |    ep_rew_mean     | -26.9    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 17       |
# |    time_elapsed    | 540      |
# |    total_timesteps | 9195     |
# | train/             |          |
# |    actor_loss      | 1.98     |
# |    critic_loss     | 0.0122   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9094     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.1     |
# |    ep_rew_mean     | -26.4    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 16       |
# |    time_elapsed    | 551      |
# |    total_timesteps | 9354     |
# | train/             |          |
# |    actor_loss      | 1.88     |
# |    critic_loss     | 0.0269   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9253     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.6     |
# |    ep_rew_mean     | -25.3    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 16       |
# |    time_elapsed    | 568      |
# |    total_timesteps | 9588     |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 0.00927  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9487     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.2     |
# |    ep_rew_mean     | -25.4    |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 16       |
# |    time_elapsed    | 582      |
# |    total_timesteps | 9768     |
# | train/             |          |
# |    actor_loss      | 1.96     |
# |    critic_loss     | 0.00958  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9667     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.3     |
# |    ep_rew_mean     | -25.4    |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 16       |
# |    time_elapsed    | 592      |
# |    total_timesteps | 9914     |
# | train/             |          |
# |    actor_loss      | 1.83     |
# |    critic_loss     | 0.0542   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9813     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.9     |
# |    ep_rew_mean     | -20.9    |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 16       |
# |    time_elapsed    | 614      |
# |    total_timesteps | 10239    |
# | train/             |          |
# |    actor_loss      | 1.93     |
# |    critic_loss     | 0.00799  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10138    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.4     |
# |    ep_rew_mean     | -21.7    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 16       |
# |    time_elapsed    | 660      |
# |    total_timesteps | 10857    |
# | train/             |          |
# |    actor_loss      | 1.76     |
# |    critic_loss     | 0.0128   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10756    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.2     |
# |    ep_rew_mean     | -23.1    |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 17       |
# |    time_elapsed    | 677      |
# |    total_timesteps | 11594    |
# | train/             |          |
# |    actor_loss      | 1.79     |
# |    critic_loss     | 0.00887  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11493    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.4     |
# |    ep_rew_mean     | -23.2    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 17       |
# |    time_elapsed    | 694      |
# |    total_timesteps | 12180    |
# | train/             |          |
# |    actor_loss      | 1.76     |
# |    critic_loss     | 0.0171   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12079    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.8     |
# |    ep_rew_mean     | -23.6    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 17       |
# |    time_elapsed    | 720      |
# |    total_timesteps | 12528    |
# | train/             |          |
# |    actor_loss      | 1.69     |
# |    critic_loss     | 0.0073   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12427    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.9     |
# |    ep_rew_mean     | -24.6    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 17       |
# |    time_elapsed    | 770      |
# |    total_timesteps | 13202    |
# | train/             |          |
# |    actor_loss      | 1.67     |
# |    critic_loss     | 0.0139   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13101    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.9     |
# |    ep_rew_mean     | -24.5    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 17       |
# |    time_elapsed    | 778      |
# |    total_timesteps | 13308    |
# | train/             |          |
# |    actor_loss      | 1.67     |
# |    critic_loss     | 0.0128   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13207    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.4     |
# |    ep_rew_mean     | -24.6    |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 17       |
# |    time_elapsed    | 786      |
# |    total_timesteps | 13581    |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.0144   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13480    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.3     |
# |    ep_rew_mean     | -24.2    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 17       |
# |    time_elapsed    | 793      |
# |    total_timesteps | 13901    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.0131   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.1     |
# |    ep_rew_mean     | -25.3    |
# |    success_rate    | 0.13     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 17       |
# |    time_elapsed    | 817      |
# |    total_timesteps | 14559    |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 0.0795   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14458    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.6     |
# |    ep_rew_mean     | -26.5    |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 17       |
# |    time_elapsed    | 852      |
# |    total_timesteps | 15290    |
# | train/             |          |
# |    actor_loss      | 1.67     |
# |    critic_loss     | 0.0139   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15189    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.8     |
# |    ep_rew_mean     | -26      |
# |    success_rate    | 0.17     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 17       |
# |    time_elapsed    | 861      |
# |    total_timesteps | 15410    |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.00825  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15309    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.1     |
# |    ep_rew_mean     | -26.6    |
# |    success_rate    | 0.18     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 17       |
# |    time_elapsed    | 892      |
# |    total_timesteps | 15814    |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.00877  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15713    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95       |
# |    ep_rew_mean     | -26.8    |
# |    success_rate    | 0.19     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 17       |
# |    time_elapsed    | 943      |
# |    total_timesteps | 16919    |
# | train/             |          |
# |    actor_loss      | 1.51     |
# |    critic_loss     | 0.0485   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16818    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.2     |
# |    ep_rew_mean     | -27.3    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 18       |
# |    time_elapsed    | 980      |
# |    total_timesteps | 17795    |
# | train/             |          |
# |    actor_loss      | 1.48     |
# |    critic_loss     | 0.00942  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17694    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0.2      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 18       |
# |    time_elapsed    | 1001     |
# |    total_timesteps | 18422    |
# | train/             |          |
# |    actor_loss      | 1.62     |
# |    critic_loss     | 0.0119   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18321    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -28.7    |
# |    success_rate    | 0.23     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 18       |
# |    time_elapsed    | 1018     |
# |    total_timesteps | 19005    |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.0105   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18904    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 108      |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0.27     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 18       |
# |    time_elapsed    | 1021     |
# |    total_timesteps | 19107    |
# | train/             |          |
# |    actor_loss      | 1.42     |
# |    critic_loss     | 0.0107   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19006    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | -28.7    |
# |    success_rate    | 0.29     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 19       |
# |    time_elapsed    | 1053     |
# |    total_timesteps | 20166    |
# | train/             |          |
# |    actor_loss      | 1.31     |
# |    critic_loss     | 0.0452   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20065    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -29.1    |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 19       |
# |    time_elapsed    | 1068     |
# |    total_timesteps | 20851    |
# | train/             |          |
# |    actor_loss      | 1.35     |
# |    critic_loss     | 0.00848  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20750    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | -29.4    |
# |    success_rate    | 0.32     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 19       |
# |    time_elapsed    | 1080     |
# |    total_timesteps | 21381    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00705  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21280    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | -30      |
# |    success_rate    | 0.34     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 20       |
# |    time_elapsed    | 1094     |
# |    total_timesteps | 22005    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.0168   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21904    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | -30.6    |
# |    success_rate    | 0.35     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 20       |
# |    time_elapsed    | 1107     |
# |    total_timesteps | 22605    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00892  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22504    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | -30.2    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 20       |
# |    time_elapsed    | 1109     |
# |    total_timesteps | 22691    |
# | train/             |          |
# |    actor_loss      | 1.38     |
# |    critic_loss     | 0.015    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22590    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 135      |
# |    ep_rew_mean     | -30.9    |
# |    success_rate    | 0.37     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 20       |
# |    time_elapsed    | 1125     |
# |    total_timesteps | 23385    |
# | train/             |          |
# |    actor_loss      | 1.46     |
# |    critic_loss     | 0.00562  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23284    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -30.5    |
# |    success_rate    | 0.36     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 20       |
# |    time_elapsed    | 1128     |
# |    total_timesteps | 23496    |
# | train/             |          |
# |    actor_loss      | 1.31     |
# |    critic_loss     | 0.00974  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23395    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 132      |
# |    ep_rew_mean     | -30.3    |
# |    success_rate    | 0.38     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 21       |
# |    time_elapsed    | 1142     |
# |    total_timesteps | 24098    |
# | train/             |          |
# |    actor_loss      | 1.37     |
# |    critic_loss     | 0.0138   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23997    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | -28.4    |
# |    success_rate    | 0.41     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 21       |
# |    time_elapsed    | 1144     |
# |    total_timesteps | 24189    |
# | train/             |          |
# |    actor_loss      | 1.32     |
# |    critic_loss     | 0.00659  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24088    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | -27.8    |
# |    success_rate    | 0.42     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 21       |
# |    time_elapsed    | 1148     |
# |    total_timesteps | 24346    |
# | train/             |          |
# |    actor_loss      | 1.3      |
# |    critic_loss     | 0.00841  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24245    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 21       |
# |    time_elapsed    | 1168     |
# |    total_timesteps | 25201    |
# | train/             |          |
# |    actor_loss      | 1.37     |
# |    critic_loss     | 0.00533  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25100    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -29      |
# |    success_rate    | 0.44     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 22       |
# |    time_elapsed    | 1199     |
# |    total_timesteps | 26522    |
# | train/             |          |
# |    actor_loss      | 1.27     |
# |    critic_loss     | 0.00837  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26421    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -30.2    |
# |    success_rate    | 0.45     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 22       |
# |    time_elapsed    | 1226     |
# |    total_timesteps | 27461    |
# | train/             |          |
# |    actor_loss      | 1.39     |
# |    critic_loss     | 0.0154   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27360    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | -30.6    |
# |    success_rate    | 0.47     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 22       |
# |    time_elapsed    | 1240     |
# |    total_timesteps | 28034    |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.0112   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27933    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -30      |
# |    success_rate    | 0.51     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 22       |
# |    time_elapsed    | 1242     |
# |    total_timesteps | 28136    |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.00711  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28035    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | -28.8    |
# |    success_rate    | 0.54     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 22       |
# |    time_elapsed    | 1246     |
# |    total_timesteps | 28309    |
# | train/             |          |
# |    actor_loss      | 1.35     |
# |    critic_loss     | 0.0269   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28208    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -27.6    |
# |    success_rate    | 0.57     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 22       |
# |    time_elapsed    | 1253     |
# |    total_timesteps | 28594    |
# | train/             |          |
# |    actor_loss      | 1.28     |
# |    critic_loss     | 0.0051   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28493    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | -28.4    |
# |    success_rate    | 0.57     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 23       |
# |    time_elapsed    | 1266     |
# |    total_timesteps | 29186    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.00627  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29085    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0.58     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 23       |
# |    time_elapsed    | 1281     |
# |    total_timesteps | 29880    |
# | train/             |          |
# |    actor_loss      | 1.36     |
# |    critic_loss     | 0.00817  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29779    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | -26.5    |
# |    success_rate    | 0.61     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 23       |
# |    time_elapsed    | 1283     |
# |    total_timesteps | 29958    |
# | train/             |          |
# |    actor_loss      | 1.25     |
# |    critic_loss     | 0.0457   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29857    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | -25.6    |
# |    success_rate    | 0.61     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 23       |
# |    time_elapsed    | 1292     |
# |    total_timesteps | 30375    |
# | train/             |          |
# |    actor_loss      | 1.28     |
# |    critic_loss     | 0.00603  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30274    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -24.9    |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 23       |
# |    time_elapsed    | 1300     |
# |    total_timesteps | 30715    |
# | train/             |          |
# |    actor_loss      | 1.27     |
# |    critic_loss     | 0.00667  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30614    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -24.4    |
# |    success_rate    | 0.63     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 23       |
# |    time_elapsed    | 1306     |
# |    total_timesteps | 30923    |
# | train/             |          |
# |    actor_loss      | 1.32     |
# |    critic_loss     | 0.0101   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30822    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 128      |
# |    ep_rew_mean     | -25.8    |
# |    success_rate    | 0.62     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 24       |
# |    time_elapsed    | 1327     |
# |    total_timesteps | 31881    |
# | train/             |          |
# |    actor_loss      | 1.31     |
# |    critic_loss     | 0.00946  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31780    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -24.8    |
# |    success_rate    | 0.64     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 24       |
# |    time_elapsed    | 1335     |
# |    total_timesteps | 32257    |
# | train/             |          |
# |    actor_loss      | 1.29     |
# |    critic_loss     | 0.00738  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 32156    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | -24.2    |
# |    success_rate    | 0.66     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 24       |
# |    time_elapsed    | 1342     |
# |    total_timesteps | 32573    |
# | train/             |          |
# |    actor_loss      | 1.41     |
# |    critic_loss     | 0.005    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 32472    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -24.8    |
# |    success_rate    | 0.66     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 24       |
# |    time_elapsed    | 1358     |
# |    total_timesteps | 33265    |
# | train/             |          |
# |    actor_loss      | 1.29     |
# |    critic_loss     | 0.0093   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 33164    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 114      |
# ...
# | train/             |          |
# |    actor_loss      | 0.596    |
# |    critic_loss     | 0.0109   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 196267   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -8.34    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 6976     |
# |    fps             | 25       |
# |    time_elapsed    | 7583     |
# |    total_timesteps | 196456   |
# | train/             |          |
# |    actor_loss      | 0.619    |
# |    critic_loss     | 0.0162   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 196355   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.8     |
# |    ep_rew_mean     | -8.34    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 6980     |
# |    fps             | 25       |
# |    time_elapsed    | 7586     |
# |    total_timesteps | 196549   |
# | train/             |          |
# |    actor_loss      | 0.541    |
# |    critic_loss     | 0.0208   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 196448   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.7     |
# |    ep_rew_mean     | -8.99    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 6984     |
# |    fps             | 25       |
# |    time_elapsed    | 7603     |
# |    total_timesteps | 197114   |
# | train/             |          |
# |    actor_loss      | 0.667    |
# |    critic_loss     | 0.0103   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197013   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.6     |
# |    ep_rew_mean     | -8.97    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 6988     |
# |    fps             | 25       |
# |    time_elapsed    | 7605     |
# |    total_timesteps | 197180   |
# | train/             |          |
# |    actor_loss      | 0.309    |
# |    critic_loss     | 0.0125   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197079   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.7     |
# |    ep_rew_mean     | -8.99    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 6992     |
# |    fps             | 25       |
# |    time_elapsed    | 7608     |
# |    total_timesteps | 197275   |
# | train/             |          |
# |    actor_loss      | 0.442    |
# |    critic_loss     | 0.00606  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197174   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.5     |
# |    ep_rew_mean     | -8.88    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 6996     |
# |    fps             | 25       |
# |    time_elapsed    | 7611     |
# |    total_timesteps | 197367   |
# | train/             |          |
# |    actor_loss      | 0.292    |
# |    critic_loss     | 0.0247   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197266   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.2     |
# |    ep_rew_mean     | -8.88    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 7000     |
# |    fps             | 25       |
# |    time_elapsed    | 7614     |
# |    total_timesteps | 197479   |
# | train/             |          |
# |    actor_loss      | 0.452    |
# |    critic_loss     | 0.00737  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197378   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.7     |
# |    ep_rew_mean     | -8.78    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 7004     |
# |    fps             | 25       |
# |    time_elapsed    | 7617     |
# |    total_timesteps | 197569   |
# | train/             |          |
# |    actor_loss      | 0.304    |
# |    critic_loss     | 0.0106   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197468   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.6     |
# |    ep_rew_mean     | -8.76    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 7008     |
# |    fps             | 25       |
# |    time_elapsed    | 7620     |
# |    total_timesteps | 197645   |
# | train/             |          |
# |    actor_loss      | 0.345    |
# |    critic_loss     | 0.00972  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197544   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.5     |
# |    ep_rew_mean     | -9.34    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7012     |
# |    fps             | 25       |
# |    time_elapsed    | 7637     |
# |    total_timesteps | 198202   |
# | train/             |          |
# |    actor_loss      | 0.221    |
# |    critic_loss     | 0.0162   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198101   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | -9.36    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 7016     |
# |    fps             | 25       |
# |    time_elapsed    | 7640     |
# |    total_timesteps | 198317   |
# | train/             |          |
# |    actor_loss      | 0.0971   |
# |    critic_loss     | 0.0141   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198216   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | -9.4     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7020     |
# |    fps             | 25       |
# |    time_elapsed    | 7643     |
# |    total_timesteps | 198390   |
# | train/             |          |
# |    actor_loss      | 0.27     |
# |    critic_loss     | 0.025    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198289   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | -9.49    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7024     |
# |    fps             | 25       |
# |    time_elapsed    | 7648     |
# |    total_timesteps | 198579   |
# | train/             |          |
# |    actor_loss      | 0.155    |
# |    critic_loss     | 0.00907  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198478   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.8     |
# |    ep_rew_mean     | -9.61    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 7028     |
# |    fps             | 25       |
# |    time_elapsed    | 7651     |
# |    total_timesteps | 198668   |
# | train/             |          |
# |    actor_loss      | 0.168    |
# |    critic_loss     | 0.0073   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198567   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.5     |
# |    ep_rew_mean     | -9.59    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 7032     |
# |    fps             | 25       |
# |    time_elapsed    | 7653     |
# |    total_timesteps | 198743   |
# | train/             |          |
# |    actor_loss      | 0.294    |
# |    critic_loss     | 0.00849  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198642   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | -9.41    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7036     |
# |    fps             | 25       |
# |    time_elapsed    | 7656     |
# |    total_timesteps | 198816   |
# | train/             |          |
# |    actor_loss      | 0.405    |
# |    critic_loss     | 0.0108   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198715   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.9     |
# |    ep_rew_mean     | -9.41    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7040     |
# |    fps             | 25       |
# |    time_elapsed    | 7658     |
# |    total_timesteps | 198899   |
# | train/             |          |
# |    actor_loss      | 0.0606   |
# |    critic_loss     | 0.0083   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198798   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.6     |
# |    ep_rew_mean     | -9.39    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7044     |
# |    fps             | 25       |
# |    time_elapsed    | 7660     |
# |    total_timesteps | 198984   |
# | train/             |          |
# |    actor_loss      | 0.493    |
# |    critic_loss     | 0.0135   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198883   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.5     |
# |    ep_rew_mean     | -9.43    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 7048     |
# |    fps             | 25       |
# |    time_elapsed    | 7663     |
# |    total_timesteps | 199075   |
# | train/             |          |
# |    actor_loss      | 0.178    |
# |    critic_loss     | 0.0118   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198974   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | -9.35    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7052     |
# |    fps             | 25       |
# |    time_elapsed    | 7665     |
# |    total_timesteps | 199145   |
# | train/             |          |
# |    actor_loss      | 0.276    |
# |    critic_loss     | 0.017    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199044   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34       |
# |    ep_rew_mean     | -9.27    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7056     |
# |    fps             | 25       |
# |    time_elapsed    | 7667     |
# |    total_timesteps | 199220   |
# | train/             |          |
# |    actor_loss      | 0.32     |
# |    critic_loss     | 0.011    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199119   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.7     |
# |    ep_rew_mean     | -8.92    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7060     |
# |    fps             | 25       |
# |    time_elapsed    | 7670     |
# |    total_timesteps | 199304   |
# | train/             |          |
# |    actor_loss      | 0.184    |
# |    critic_loss     | 0.00696  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199203   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.7     |
# |    ep_rew_mean     | -8.98    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7064     |
# |    fps             | 25       |
# |    time_elapsed    | 7672     |
# |    total_timesteps | 199381   |
# | train/             |          |
# |    actor_loss      | 0.0701   |
# |    critic_loss     | 0.0164   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199280   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.9     |
# |    ep_rew_mean     | -9.16    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 7068     |
# |    fps             | 25       |
# |    time_elapsed    | 7675     |
# |    total_timesteps | 199476   |
# | train/             |          |
# |    actor_loss      | 0.305    |
# |    critic_loss     | 0.0127   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199375   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32       |
# |    ep_rew_mean     | -9.19    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 7072     |
# |    fps             | 25       |
# |    time_elapsed    | 7678     |
# |    total_timesteps | 199568   |
# | train/             |          |
# |    actor_loss      | 0.309    |
# |    critic_loss     | 0.0201   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199467   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.2     |
# |    ep_rew_mean     | -9.22    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 7076     |
# |    fps             | 25       |
# |    time_elapsed    | 7681     |
# |    total_timesteps | 199674   |
# | train/             |          |
# |    actor_loss      | 0.274    |
# |    critic_loss     | 0.0147   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199573   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.1     |
# |    ep_rew_mean     | -9.08    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 7080     |
# |    fps             | 25       |
# |    time_elapsed    | 7683     |
# |    total_timesteps | 199756   |
# | train/             |          |
# |    actor_loss      | 0.311    |
# |    critic_loss     | 0.0163   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199655   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | -8.42    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 7084     |
# |    fps             | 25       |
# |    time_elapsed    | 7685     |
# |    total_timesteps | 199826   |
# | train/             |          |
# |    actor_loss      | 0.29     |
# |    critic_loss     | 0.017    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199725   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | -8.51    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 7088     |
# |    fps             | 26       |
# |    time_elapsed    | 7688     |
# |    total_timesteps | 199909   |
# | train/             |          |
# |    actor_loss      | 0.239    |
# |    critic_loss     | 0.0153   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199808   |
# ---------------------------------

# %%
# Load saved model
model = DDPG.load('her_ddpg_highway', env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# #### Evaluate DDPG agent

# %%
# we use the gym >v.26 API here. Note that you could also wrap the env in a DummyVecEnv
# which allows you to use the old gym API a simplified API
obs, _ = env.reset()

# Evaluate the agent
episode_reward = 0
for _ in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = truncated or terminated
    episode_reward += reward
    if done or info.get("is_success", False):
        print("Reward:", episode_reward, "Success?", info.get("is_success", False))
        episode_reward = 0.0
        obs, _ = env.reset()
# Out:
# Reward: -10.88932621376994 Success? True
# Reward: -7.232710411189086 Success? True
# Reward: -3.5694489330911026 Success? True
# Reward: -4.57312157455117 Success? True
# Reward: -5.470549049887844 Success? True
# Reward: -3.513680684665023 Success? True
# Reward: -8.487132322612954 Success? True
# Reward: -4.604462292015917 Success? True
# Reward: -6.044720056588108 Success? True
# Reward: -5.87483292411637 Success? True
# Reward: -5.194191953385466 Success? True
# Reward: -7.833608261846191 Success? True
# Reward: -5.794497177199117 Success? True
# Reward: -3.6651461906779335 Success? True
# Reward: -4.5692794591671095 Success? True
# Reward: -8.759227017443811 Success? True
# Reward: -5.777826507868408 Success? True
# Reward: -6.765293100222839 Success? True
# Reward: -10.206196430375389 Success? True
# Reward: -7.782004360009789 Success? True
# Reward: -5.496592646557844 Success? True
# Reward: -4.074065411663049 Success? True
# Reward: -10.137375746957051 Success? True
# Reward: -6.8234976561469 Success? True
# Reward: -4.186748347857564 Success? True
# Reward: -5.367912621943328 Success? True
# Reward: -4.648053098888309 Success? True
# Reward: -8.807574810936595 Success? True
# Reward: -7.3095290451504535 Success? True
# Reward: -8.69131423461289 Success? True
# Reward: -9.483036950394183 Success? True
